# %%
import pandas as pd

# Replace 'your_file.xlsx' with the path to your Excel file
df = pd.read_excel('driver_data_base_4_25.xlsx')

# %% [markdown]
# Empirical answer with the following assumptions:
#
# No driver who is impossible to be the answer is picked.
#
# "Best" is defined by lowest average number of guesses while always winning (any starting driver can always win we find)

# %%
import itertools

# Function to group by criteria
def group_by_criteria(row):
    driver, team, flag, birth_year, start_year, wins, car_number = row['driver'], row['team'], row['flag'], row['birth year'], row['start year'], row['wins'], row['car_number']
    
    # Define the conditions
    conditions = {
        'team': [
            (df['team'] == team), 
            (df['former_team'].str.contains(team) & (df['team'] != team)), 
            (~df['former_team'].str.contains(team) & (df['team'] != team))
        ],
        'flag': [(df['flag'] == flag), (df['flag'] != flag)],
        'birth_year': [(df['birth year'] == birth_year), (df['birth year'] < birth_year), (df['birth year'] > birth_year)],
        'start_year': [(df['start year'] == start_year), (df['start year'] < start_year), (df['start year'] > start_year)],
        'wins': [(df['wins'] == wins), (df['wins'] < wins), (df['wins'] > wins)],
        'car_number': [(df['car_number'] == car_number), (df['car_number'] > car_number), (df['car_number'] < car_number)],
    }
    
    # Generate all possible combinations of conditions
    all_conditions = [conditions[key] for key in conditions]
    all_combinations = list(itertools.product(*all_conditions))
    
    # Calculate max group size for all possible combinations
    max_group_size = 0
    for combination in all_combinations:
        # Reduce the combination to a single boolean mask using functools.reduce and logical AND
        combined_mask = pd.Series([True] * len(df))  # Start with a mask that is all True
        for condition in combination:
            combined_mask &= condition  # Apply logical AND to combine conditions
        
        # Exclude the current row (driver) from the group size calculation
        combined_mask &= (df['driver'] != driver)
        
        # Update max_group_size with the size of the current group
        current_group_size = combined_mask.sum()
        max_group_size = max(max_group_size, current_group_size)
        
    return max_group_size

# %%
# Apply function and create new column for largest group size
df['largest_group_size'] = df.apply(group_by_criteria, axis=1)

# Print the smallest value in the 'largest_group_size' column
print(df['largest_group_size'].min())
# Out:
# 7

# %%
from collections import defaultdict
def criteria_function(driver, df):
    # Get the specific driver details for comparison
    driver_details = df[df['driver'] == driver].iloc[0]

    groups = defaultdict(list)
    for _, row in df.iterrows():
        groups[
            (
                'same team' if row['team'] == driver_details['team'] else 
                'previous team' if driver_details['team'] in row['former_team'].split(', ') else 
                'different team',
                'same flag' if row['flag'] == driver_details['flag'] else 'different flag',
                'same birth year' if row['birth year'] == driver_details['birth year'] else 'later birth year' if row['birth year'] > driver_details['birth year'] else 'earlier birth year',
                'same start year' if row['start year'] == driver_details['start year'] else 'later start year' if row['start year'] > driver_details['start year'] else 'earlier start year',
                'same wins' if row['wins'] == driver_details['wins'] else 'more wins' if row['wins'] > driver_details['wins'] else 'fewer wins',
                'same car number' if row['car_number'] == driver_details['car_number'] else 'higher car number' if row['car_number'] > driver_details['car_number'] else 'lower car number'
            )
        ].append(row['driver'])

    # Convert the defaultdict to a standard dict and remove the key for the driver in question
    groups = dict(groups)
    group_key_for_driver = next((k for k, v in groups.items() if driver in v), None)
    if group_key_for_driver is not None:
        groups.pop(group_key_for_driver)

    answer = []
    group_size_sum = 0
    num_groups = 0
    for key in groups:
        answer.append(groups[key])
        group_size_sum += len(groups[key])
        num_groups += 1
    #ave_group_size = group_size_sum/num_groups
    return answer #, ave_group_size

# %%
def longest_path_in_shortest_tree(drivers, df, criteria_function, path_length=1):
    long_term_sum = 50000
    long_term_num = 1
    # If only one driver is left, we have reached a leaf node
    if len(drivers) <= 3:
        # we'll avoid recurssion because these cases are deterministic.
        if len(drivers) == 1:
            return path_length, path_length, 1
        elif len(drivers) == 2:
            longest_path = path_length+1
            long_term_sum = path_length + path_length+1
            long_term_num = 2
            return longest_path, long_term_sum, long_term_num
        elif len(drivers) == 3:
            # pick the middle car_number or either car_number that is in a tie and it will force the below situation, so we shortcut
            longest_path = path_length+1
            long_term_sum = path_length + path_length+1 + path_length+1
            long_term_num = 3
            return longest_path, long_term_sum, long_term_num
        else:
            raise ValueError('A value error occurred')
    longest_path = float('inf')
    best_driver = 'me'
    for driver in drivers:
        sum_lengths = path_length # These account for getting the driver correct
        num_lengths = 1
        # Generate groups using the criteria_function
        groups = criteria_function(driver, df)
        # If criteria_function results in a group of size 1,
        # it means we have identified a unique driver
        temp_longest_path = 1
        for subgroup in groups:
            if len(subgroup) > 3:
                subgroup_df = df[df['driver'].isin(subgroup)]
                path, temp_sum, temp_num = longest_path_in_shortest_tree(subgroup, subgroup_df, criteria_function, path_length + 1)
                if path > temp_longest_path:
                    sum_lengths += temp_sum
                    num_lengths += temp_num
                    temp_longest_path = path
            else:
                # Our answers can be determined without further recurssion.
                if len(subgroup) == 3:
                    temp_longest_path = max(temp_longest_path, path_length + 3)
                    sum_lengths += 3*path_length + 5 # one will be right, two will be wrong, so one will be path_length +1; the other 2, path_length +2
                    num_lengths += 3
                elif len(subgroup) == 2:
                    temp_longest_path = max(temp_longest_path, path_length + 2)
                    sum_lengths += 2*path_length + 3 # one will be right, one will be wrong, so one will be path_length +1; the other path_length +2
                    num_lengths += 2
                elif len(subgroup) == 1:
                    temp_longest_path = max(temp_longest_path, path_length + 1)
                    sum_lengths += path_length + 1
                    num_lengths += 1
                else:
                    raise ValueError('A value error occurred')
        if longest_path > temp_longest_path:
            longest_path = temp_longest_path
            # I am forcing us to use average for the shortest tree here.
            long_term_sum = sum_lengths
            long_term_num = num_lengths
        elif longest_path == temp_longest_path:
            # This will only replace the average if it's the best of the shortest trees.
            if sum_lengths/num_lengths < long_term_sum/long_term_num:
                long_term_sum = sum_lengths
                long_term_num = num_lengths
    return longest_path, long_term_sum, long_term_num

# %%
drivers = ['Romain Grosjean',
  'Marcus Ericsson',
  'Nikita Mazepin',
  'Kamui Kobayashi',
  'Pierre Gasly',
  'Sergio Perez',
  'Felipe Nasr',
  'Pastor Maldonado',
  'Jules Bianchi',
  'Lance Stroll',
  'Felipe Massa',
  'Kevin Magnussen',
  'Esteban Gutierrez',
  'Nyck de Vries',
  'Yuki Tsunoda',
  'Alexander Albon',
  'Jean-Eric Vergne',
  'Daniil Kvyat',
  'Nico Hulkenberg',
  'Will Stevens',
  'Brendon Hartley',
  'Jolyon Palmer',
  'Esteban Ocon',
  'Sergey Sirotkin',
  'Oliver Bearman',
  'Liam Lawson',
  'Paul di Resta',
  'Andre Lotterer',
  'Mick Schumacher',
  'Pietro Fittipaldi',
  'Alexander Rossi',
  'Carlos Sainz',
  'George Russell',
  'Oscar Piastri',
  'Rio Haryanto',
  'Jack Aitken',
  'Pascal Wehrlein',
  'Roberto Merhi',
  'Adrian Sutil']
sub_df = df[df['driver'].isin(drivers)]
a, b, c = longest_path_in_shortest_tree(drivers, sub_df, criteria_function, path_length=2)
print(a, b/c)
# Out:
# 5 3.125

# %%
criteria_function('Kimi Raikkonen', df)
# Out:
# [['Stoffel Vandoorne',
#   'Logan Sargeant',
#   'Daniel Ricciardo',
#   'Max Chilton',
#   'Lando Norris',
#   'Nicholas Latifi'],
#  ['Sebastian Vettel', 'Nico Rosberg'],
#  ['Romain Grosjean',
#   'Marcus Ericsson',
#   'Nikita Mazepin',
#   'Kamui Kobayashi',
#   'Pierre Gasly',
#   'Sergio Perez',
#   'Felipe Nasr',
#   'Pastor Maldonado',
#   'Jules Bianchi',
#   'Lance Stroll',
#   'Felipe Massa',
#   'Kevin Magnussen',
#   'Esteban Gutierrez',
#   'Nyck de Vries',
#   'Yuki Tsunoda',
#   'Alexander Albon',
#   'Jean-Eric Vergne',
#   'Daniil Kvyat',
#   'Nico Hulkenberg',
#   'Will Stevens',
#   'Brendon Hartley',
#   'Jolyon Palmer',
#   'Esteban Ocon',
#   'Sergey Sirotkin',
#   'Oliver Bearman',
#   'Liam Lawson',
#   'Paul di Resta',
#   'Andre Lotterer',
#   'Mick Schumacher',
#   'Pietro Fittipaldi',
#   'Alexander Rossi',
#   'Carlos Sainz',
#   'George Russell',
#   'Oscar Piastri',
#   'Rio Haryanto',
#   'Jack Aitken',
#   'Pascal Wehrlein',
#   'Roberto Merhi',
#   'Adrian Sutil'],
#  ['Fernando Alonso'],
#  ['Charles Leclerc', 'Zhou Guanyu'],
#  ['Jenson Button'],
#  ['Max Verstappen', 'Lewis Hamilton'],
#  ['Valtteri Bottas'],
#  ['Robert Kubica', 'Antonio Giovinazzi']]

# %%
final_ave = float('inf')
winning_driver = []
final_answer = float('inf')
winning_ave_driver = []
for i in range(8, 9):
    answer = 1
    driver_sum = 1 # to handle the case we got it right initially as this isn't covered right now
    driver_num = 1
    for drivers in criteria_function(df['driver'].iloc[i], df):
        print(f"Drivers {drivers}")
        df['driver'].isin(drivers)
        sub_df = df[df['driver'].isin(drivers)]
        temp, temp_sum, temp_num = longest_path_in_shortest_tree(drivers, sub_df, criteria_function, path_length=2)
        driver_sum += temp_sum
        driver_num += temp_num
        if temp > answer:
            answer = temp
    print(f"answer {answer, driver_sum/driver_num, df['driver'].iloc[i]}")
    if answer == final_answer:
        winning_driver.append(df['driver'].iloc[i])
    if answer < final_answer:
        final_answer = answer
        winning_driver = [df['driver'].iloc[i]]
    if driver_sum/driver_num == final_ave:
        print('sum')
        print(df['driver'].iloc[i])
        winning_ave_driver.append(df['driver'].iloc[i])
    if driver_sum/driver_num < final_ave:
        print('sum')
        print(df['driver'].iloc[i])
        final_ave = driver_sum/driver_num
        winning_ave_driver = [df['driver'].iloc[i]]
print(final_ave, winning_ave_driver, final_answer, winning_driver)
# Out:
# Drivers ['Stoffel Vandoorne', 'Logan Sargeant', 'Daniel Ricciardo', 'Max Chilton', 'Lando Norris', 'Nicholas Latifi']
# Drivers ['Sebastian Vettel', 'Nico Rosberg']
# Drivers ['Romain Grosjean', 'Marcus Ericsson', 'Nikita Mazepin', 'Kamui Kobayashi', 'Pierre Gasly', 'Sergio Perez', 'Felipe Nasr', 'Pastor Maldonado', 'Jules Bianchi', 'Lance Stroll', 'Felipe Massa', 'Kevin Magnussen', 'Esteban Gutierrez', 'Nyck de Vries', 'Yuki Tsunoda', 'Alexander Albon', 'Jean-Eric Vergne', 'Daniil Kvyat', 'Nico Hulkenberg', 'Will Stevens', 'Brendon Hartley', 'Jolyon Palmer', 'Esteban Ocon', 'Sergey Sirotkin', 'Oliver Bearman', 'Liam Lawson', 'Paul di Resta', 'Andre Lotterer', 'Mick Schumacher', 'Pietro Fittipaldi', 'Alexander Rossi', 'Carlos Sainz', 'George Russell', 'Oscar Piastri', 'Rio Haryanto', 'Jack Aitken', 'Pascal Wehrlein', 'Roberto Merhi', 'Adrian Sutil']
# Drivers ['Fernando Alonso']
# Drivers ['Charles Leclerc', 'Zhou Guanyu']
# Drivers ['Jenson Button']
# Drivers ['Max Verstappen', 'Lewis Hamilton']
# Drivers ['Valtteri Bottas']
# Drivers ['Robert Kubica', 'Antonio Giovinazzi']
# answer (5, 2.764705882352941, 'Kimi Raikkonen')
# sum
# Kimi Raikkonen
# 2.764705882352941 ['Kimi Raikkonen'] 5 ['Kimi Raikkonen']

# %%
min_record = 100.0
driver_record = ''
for driver in df['driver']:
    temp = criteria_function(driver, df)[-1]
    print(driver, temp, min_record)
    if temp < min_record:
        min_record = temp
        driver_record = driver
print(driver_record)
print(min_record)

# %% [markdown]
# Now we build and use our robot player:

# %%
import random
import numpy as np
import gym
from gym import spaces
import pandas as pd

class F1MysteryDriverEnv(gym.Env):
    metadata = {'render.modes': ['human']}
    
    def __init__(self, df):
        super(F1MysteryDriverEnv, self).__init__()
        
        self.df = df
        self.action_space = spaces.Discrete(len(df['driver']))  # Drivers are unique
        self.observation_space = spaces.Dict({
            "attempts": spaces.Discrete(6),  # A max of 6 attempts
            "feedback": spaces.MultiDiscrete([3] * 6)  # Feedback for each hint category
        })
        self.reset()

    def reset(self):
        self.state = {
            "mystery_driver": random.choice(self.df['driver']),
            "attempts": 0,
        }
        self.state["mystery_driver_info"] = self.df.loc[
            self.df['driver'] == self.state["mystery_driver"],
            ['car_number', 'start year', 'birth year', 'flag', 'team', 'wins']
        ].values[0]
        
        initial_observation = {
            "attempts": self.state["attempts"],
            "feedback": np.zeros(6)  # Initial feedback is all zeros (no information)
        }
        return initial_observation

    def step(self, action):
        assert self.action_space.contains(action)
        entered_driver = self.df['driver'].iloc[action]  # Map action to the driver name
        reward = 0
        done = False
        info = {}
        
        # Initialize feedback with whatever default you find suitable, e.g., np.zeros(6)
        feedback = np.zeros(6)
        
        if entered_driver == self.state["mystery_driver"]:
            reward = 500  # For choosing the correct driver
            done = True
            info["message"] = f"Correct! It is {self.state['mystery_driver_info']} YOU WIN!"
        else:
            self.state["attempts"] += 1
            feedback = self.get_feedback(entered_driver)  # Generate feedback based on the driver
            if self.state["attempts"] == 1:
                pass
            elif self.state["attempts"] < 6:
                reward = -100  # Negative reward for incorrect guess after the second (getting first is just luck so we don't want to differentiate between first and second)
            else:
                # The feedback calculation is already done above, so we can remove it from here
                reward = -100
                done = True
                info["message"] = "Game Over. Reached maximum attempts."
        
        observation = {
            "attempts": self.state["attempts"],
            "feedback": feedback
        }

        return observation, reward, done, info
    
    def get_feedback(self, entered_driver):
        feedback = np.zeros(6)  # We have 6 pieces of feedback

        # Number comparison
        entered_driver_number = self.df.loc[self.df['driver'] == entered_driver, 'car_number'].values[0]
        if entered_driver_number > self.state["mystery_driver_info"][0]:
            feedback[0] = -1
        elif entered_driver_number < self.state["mystery_driver_info"][0]:
            feedback[0] = 1

        # Birth year comparison
        entered_driver_birth_year = self.df.loc[self.df['driver'] == entered_driver, 'birth year'].values[0]
        if entered_driver_birth_year > self.state["mystery_driver_info"][2]:
            feedback[1] = -1
        elif entered_driver_birth_year < self.state["mystery_driver_info"][2]:
            feedback[1] = 1

        # Start year comparison
        entered_driver_start_year = self.df.loc[self.df['driver'] == entered_driver, 'start year'].values[0]
        if entered_driver_start_year > self.state["mystery_driver_info"][1]:
            feedback[2] = -1
        elif entered_driver_start_year < self.state["mystery_driver_info"][1]:
            feedback[2] = 1

        # Wins comparison
        entered_driver_wins = self.df.loc[self.df['driver'] == entered_driver, 'wins'].values[0]
        if entered_driver_wins > self.state["mystery_driver_info"][5]:
            feedback[3] = -1
        elif entered_driver_wins < self.state["mystery_driver_info"][5]:
            feedback[3] = 1

        # Flag comparison
        entered_driver_flag = self.df.loc[self.df['driver'] == entered_driver, 'flag'].values[0]
        feedback[4] = 0 if entered_driver_flag == self.state["mystery_driver_info"][3] else 1

        # Team comparison 
        entered_driver_team = self.df.loc[self.df['driver'] == entered_driver, 'team'].values[0]
        if entered_driver_team == self.state["mystery_driver_info"][4]:
            feedback[5] = 0
        else:
            feedback[5] = 1
        return feedback
        
    def render(self, mode='human'):
        # You can print out game state, feedback, or any other user-friendly information
        print(f"Attempts: {self.state['attempts']}")

    def close(self):
        # Perform any cleanup, if necessary
        pass

# A simple Q-learning agent class
class QLearningAgent:
    def __init__(self, action_space, state_space, learning_rate=0.1, discount_factor=0.99, exploration_rate=1.0, max_exploration_rate=1.0, min_exploration_rate=0.1, exploration_decay_rate=0.0001):
        self.action_space = action_space
        self.state_space = state_space
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.exploration_rate = exploration_rate
        self.max_exploration_rate = max_exploration_rate
        self.min_exploration_rate = min_exploration_rate
        self.exploration_decay_rate = exploration_decay_rate
        self.q_table = np.zeros((state_space, action_space.n))

    # QLearningAgent class - inside the class definition
    def get_state_as_int(self, observation):
        # Since feedback can be -1, 0, 1, first map these values to 0, 1, 2 for non-negative encoding
        mapped_feedback = observation['feedback'] + 1  # Shift from [-1, 0, 1] to [0, 1, 2]
        base = 3  # Now we use base 3 because we have three possible values: 0, 1, 2
        
        feedback_int = 0
        for i, val in enumerate(mapped_feedback):
            feedback_int *= base
            feedback_int += val
        
        # Calculate the state by combining attempts and feedback values
        state_int = observation['attempts'] * (base ** len(mapped_feedback)) + feedback_int
        return int(state_int)
        
    def choose_action(self, observation):
        state = self.get_state_as_int(observation)
        exploration_rate_threshold = np.random.uniform(0, 1)
        if exploration_rate_threshold > self.exploration_rate:
            action = np.argmax(self.q_table[state])  # Exploit the best known value
        else:
            action = self.action_space.sample()  # Explore action space
        return action

    def learn(self, state, action, reward, next_state, done):
        old_value = self.q_table[state, action]
        next_max = np.max(self.q_table[next_state])
        
        new_value = (1 - self.learning_rate) * old_value + self.learning_rate * (reward + self.discount_factor * next_max)
        self.q_table[state, action] = new_value
        
        if done:
            self.exploration_rate = max(self.min_exploration_rate, self.exploration_rate * self.exploration_decay_rate)

# %%
env = F1MysteryDriverEnv(df)
num_feedback_options = 3 ** len(env.observation_space.spaces['feedback'].nvec)
num_attempts = env.observation_space.spaces['attempts'].n
total_state_space_size = (num_attempts+1) * num_feedback_options
agent = QLearningAgent(env.action_space, total_state_space_size)

# %%
agent.exploration_decay_rate
# Out:
# 0.0001

# %%
number_of_episodes = 180000

# %%
for episode in range(number_of_episodes):
    observation = env.reset()
    state = int(agent.get_state_as_int(observation))
    total_reward = 500
    done = False
    steps = 0
    
    while not done and steps < num_attempts:
        action = agent.choose_action(observation)
        # If it's the first step, print out the chosen driver
        if steps == 0:
            driver_name = df['driver'].iloc[action]  # Assuming 'driver' is the column name with the driver names

        next_observation, reward, done, info = env.step(action)
        next_state = agent.get_state_as_int(next_observation)
        agent.learn(state, action, reward, next_state, done)

        state = next_state
        observation = next_observation
        total_reward += reward
        steps += 1

    if (episode + 1) % 100 == 0:
        print(f"Episode {episode + 1} finished with total reward: {total_reward}. First driver picked was {driver_name}")

    # Adjust the exploration rate
    agent.exploration_rate = max(agent.min_exploration_rate, agent.exploration_rate * np.exp(-agent.exploration_decay_rate*episode))
# Out:
# Episode 100 finished with total reward: 700. First driver picked was Fernando Alonso
# Episode 200 finished with total reward: 800. First driver picked was Will Stevens
# Episode 300 finished with total reward: 700. First driver picked was Daniil Kvyat
# Episode 400 finished with total reward: 800. First driver picked was Will Stevens
# Episode 500 finished with total reward: 0. First driver picked was Will Stevens
# Episode 600 finished with total reward: 900. First driver picked was Will Stevens
# Episode 700 finished with total reward: 600. First driver picked was Will Stevens
# Episode 800 finished with total reward: 0. First driver picked was Will Stevens
# Episode 900 finished with total reward: 600. First driver picked was Yuki Tsunoda
# Episode 1000 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 1100 finished with total reward: 800. First driver picked was Will Stevens
# Episode 1200 finished with total reward: 800. First driver picked was Pascal Wehrlein
# Episode 1300 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 1400 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 1500 finished with total reward: 0. First driver picked was Will Stevens
# Episode 1600 finished with total reward: 800. First driver picked was Will Stevens
# Episode 1700 finished with total reward: 800. First driver picked was Will Stevens
# Episode 1800 finished with total reward: 0. First driver picked was Roberto Merhi
# Episode 1900 finished with total reward: 0. First driver picked was Max Chilton
# Episode 2000 finished with total reward: 0. First driver picked was Robert Kubica
# Episode 2100 finished with total reward: 900. First driver picked was Pascal Wehrlein
# Episode 2200 finished with total reward: 700. First driver picked was Pascal Wehrlein
# Episode 2300 finished with total reward: 0. First driver picked was Esteban Gutierrez
# Episode 2400 finished with total reward: 0. First driver picked was Fernando Alonso
# Episode 2500 finished with total reward: 0. First driver picked was George Russell
# Episode 2600 finished with total reward: 700. First driver picked was Will Stevens
# Episode 2700 finished with total reward: 900. First driver picked was Will Stevens
# Episode 2800 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 2900 finished with total reward: 800. First driver picked was Will Stevens
# Episode 3000 finished with total reward: 700. First driver picked was Will Stevens
# Episode 3100 finished with total reward: 800. First driver picked was Lewis Hamilton
# Episode 3200 finished with total reward: 800. First driver picked was Will Stevens
# Episode 3300 finished with total reward: 900. First driver picked was Andre Lotterer
# Episode 3400 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 3500 finished with total reward: 600. First driver picked was Will Stevens
# Episode 3600 finished with total reward: 800. First driver picked was Will Stevens
# Episode 3700 finished with total reward: 800. First driver picked was Will Stevens
# Episode 3800 finished with total reward: 0. First driver picked was Will Stevens
# Episode 3900 finished with total reward: 0. First driver picked was Will Stevens
# Episode 4000 finished with total reward: 0. First driver picked was Will Stevens
# Episode 4100 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 4200 finished with total reward: 800. First driver picked was Will Stevens
# Episode 4300 finished with total reward: 900. First driver picked was Will Stevens
# Episode 4400 finished with total reward: 800. First driver picked was Will Stevens
# Episode 4500 finished with total reward: 700. First driver picked was Esteban Gutierrez
# Episode 4600 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 4700 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 4800 finished with total reward: 900. First driver picked was Sergey Sirotkin
# Episode 4900 finished with total reward: 0. First driver picked was Andre Lotterer
# Episode 5000 finished with total reward: 0. First driver picked was Lando Norris
# Episode 5100 finished with total reward: 600. First driver picked was Rio Haryanto
# Episode 5200 finished with total reward: 0. First driver picked was Rio Haryanto
# Episode 5300 finished with total reward: 1000. First driver picked was Adrian Sutil
# Episode 5400 finished with total reward: 700. First driver picked was Will Stevens
# Episode 5500 finished with total reward: 1000. First driver picked was Adrian Sutil
# Episode 5600 finished with total reward: 900. First driver picked was Will Stevens
# Episode 5700 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 5800 finished with total reward: 800. First driver picked was Will Stevens
# Episode 5900 finished with total reward: 700. First driver picked was Will Stevens
# Episode 6000 finished with total reward: 0. First driver picked was Will Stevens
# Episode 6100 finished with total reward: 700. First driver picked was Will Stevens
# Episode 6200 finished with total reward: 0. First driver picked was Will Stevens
# Episode 6300 finished with total reward: 600. First driver picked was Lando Norris
# Episode 6400 finished with total reward: 0. First driver picked was Will Stevens
# Episode 6500 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 6600 finished with total reward: 0. First driver picked was Will Stevens
# Episode 6700 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 6800 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 6900 finished with total reward: 800. First driver picked was Will Stevens
# Episode 7000 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 7100 finished with total reward: 800. First driver picked was Will Stevens
# Episode 7200 finished with total reward: 800. First driver picked was Romain Grosjean
# Episode 7300 finished with total reward: 900. First driver picked was Will Stevens
# Episode 7400 finished with total reward: 0. First driver picked was Will Stevens
# Episode 7500 finished with total reward: 800. First driver picked was Will Stevens
# Episode 7600 finished with total reward: 600. First driver picked was Will Stevens
# Episode 7700 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 7800 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 7900 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 8000 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 8100 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 8200 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 8300 finished with total reward: 900. First driver picked was Will Stevens
# Episode 8400 finished with total reward: 600. First driver picked was Will Stevens
# Episode 8500 finished with total reward: 700. First driver picked was Andre Lotterer
# Episode 8600 finished with total reward: 700. First driver picked was Will Stevens
# Episode 8700 finished with total reward: 0. First driver picked was Oliver Bearman
# Episode 8800 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 8900 finished with total reward: 0. First driver picked was Will Stevens
# Episode 9000 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 9100 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 9200 finished with total reward: 900. First driver picked was Will Stevens
# Episode 9300 finished with total reward: 0. First driver picked was Lewis Hamilton
# Episode 9400 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 9500 finished with total reward: 700. First driver picked was Paul di Resta
# Episode 9600 finished with total reward: 0. First driver picked was Will Stevens
# Episode 9700 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 9800 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 9900 finished with total reward: 0. First driver picked was Will Stevens
# Episode 10000 finished with total reward: 800. First driver picked was Will Stevens
# Episode 10100 finished with total reward: 0. First driver picked was Will Stevens
# Episode 10200 finished with total reward: 900. First driver picked was Robert Kubica
# Episode 10300 finished with total reward: 600. First driver picked was Andre Lotterer
# Episode 10400 finished with total reward: 700. First driver picked was Will Stevens
# Episode 10500 finished with total reward: 0. First driver picked was Lando Norris
# Episode 10600 finished with total reward: 600. First driver picked was Lewis Hamilton
# Episode 10700 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 10800 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 10900 finished with total reward: 600. First driver picked was Nikita Mazepin
# Episode 11000 finished with total reward: 800. First driver picked was Andre Lotterer
# Episode 11100 finished with total reward: 0. First driver picked was Alexander Albon
# Episode 11200 finished with total reward: 800. First driver picked was Pascal Wehrlein
# Episode 11300 finished with total reward: 0. First driver picked was Max Chilton
# Episode 11400 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 11500 finished with total reward: 800. First driver picked was Daniil Kvyat
# Episode 11600 finished with total reward: 700. First driver picked was Kevin Magnussen
# Episode 11700 finished with total reward: 0. First driver picked was Will Stevens
# Episode 11800 finished with total reward: 600. First driver picked was Pascal Wehrlein
# Episode 11900 finished with total reward: 600. First driver picked was Max Chilton
# Episode 12000 finished with total reward: 700. First driver picked was Nyck de Vries
# Episode 12100 finished with total reward: 900. First driver picked was Pascal Wehrlein
# Episode 12200 finished with total reward: 800. First driver picked was Nyck de Vries
# Episode 12300 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 12400 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 12500 finished with total reward: 0. First driver picked was Oscar Piastri
# Episode 12600 finished with total reward: 600. First driver picked was Adrian Sutil
# Episode 12700 finished with total reward: 0. First driver picked was Max Chilton
# Episode 12800 finished with total reward: 900. First driver picked was Max Verstappen
# Episode 12900 finished with total reward: 1000. First driver picked was Pascal Wehrlein
# Episode 13000 finished with total reward: 600. First driver picked was Andre Lotterer
# Episode 13100 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 13200 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 13300 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 13400 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 13500 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 13600 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 13700 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 13800 finished with total reward: 0. First driver picked was Stoffel Vandoorne
# Episode 13900 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 14000 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 14100 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 14200 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 14300 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 14400 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 14500 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 14600 finished with total reward: 900. First driver picked was Jack Aitken
# Episode 14700 finished with total reward: 600. First driver picked was Jack Aitken
# Episode 14800 finished with total reward: 700. First driver picked was Adrian Sutil
# Episode 14900 finished with total reward: 1000. First driver picked was Adrian Sutil
# Episode 15000 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 15100 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 15200 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 15300 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 15400 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 15500 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 15600 finished with total reward: 600. First driver picked was Pascal Wehrlein
# Episode 15700 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 15800 finished with total reward: 800. First driver picked was Alexander Rossi
# Episode 15900 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 16000 finished with total reward: 0. First driver picked was Logan Sargeant
# Episode 16100 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 16200 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 16300 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 16400 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 16500 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 16600 finished with total reward: 0. First driver picked was Sebastian Vettel
# Episode 16700 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 16800 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 16900 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 17000 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 17100 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 17200 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 17300 finished with total reward: 600. First driver picked was Sergey Sirotkin
# Episode 17400 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 17500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 17600 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 17700 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 17800 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 17900 finished with total reward: 900. First driver picked was Jean-Eric Vergne
# Episode 18000 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 18100 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 18200 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 18300 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 18400 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 18500 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 18600 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 18700 finished with total reward: 600. First driver picked was Esteban Gutierrez
# Episode 18800 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 18900 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 19000 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 19100 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 19200 finished with total reward: 0. First driver picked was Jean-Eric Vergne
# Episode 19300 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 19400 finished with total reward: 0. First driver picked was Max Chilton
# Episode 19500 finished with total reward: 1000. First driver picked was Nico Hulkenberg
# Episode 19600 finished with total reward: 0. First driver picked was Nicholas Latifi
# Episode 19700 finished with total reward: 0. First driver picked was Alexander Rossi
# Episode 19800 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 19900 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 20000 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 20100 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 20200 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 20300 finished with total reward: 600. First driver picked was George Russell
# Episode 20400 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 20500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 20600 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 20700 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 20800 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 20900 finished with total reward: 0. First driver picked was Yuki Tsunoda
# Episode 21000 finished with total reward: 800. First driver picked was Lance Stroll
# Episode 21100 finished with total reward: 900. First driver picked was Roberto Merhi
# Episode 21200 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 21300 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 21400 finished with total reward: 0. First driver picked was Antonio Giovinazzi
# Episode 21500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 21600 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 21700 finished with total reward: 900. First driver picked was George Russell
# Episode 21800 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 21900 finished with total reward: 0. First driver picked was Romain Grosjean
# Episode 22000 finished with total reward: 600. First driver picked was Jack Aitken
# Episode 22100 finished with total reward: 1000. First driver picked was Max Chilton
# Episode 22200 finished with total reward: 600. First driver picked was Max Chilton
# Episode 22300 finished with total reward: 800. First driver picked was Will Stevens
# Episode 22400 finished with total reward: 600. First driver picked was Paul di Resta
# Episode 22500 finished with total reward: 800. First driver picked was Mick Schumacher
# Episode 22600 finished with total reward: 600. First driver picked was Mick Schumacher
# Episode 22700 finished with total reward: 0. First driver picked was Will Stevens
# Episode 22800 finished with total reward: 0. First driver picked was Andre Lotterer
# Episode 22900 finished with total reward: 800. First driver picked was Will Stevens
# Episode 23000 finished with total reward: 0. First driver picked was Paul di Resta
# Episode 23100 finished with total reward: 700. First driver picked was George Russell
# Episode 23200 finished with total reward: 800. First driver picked was Jack Aitken
# Episode 23300 finished with total reward: 600. First driver picked was Will Stevens
# Episode 23400 finished with total reward: 600. First driver picked was Will Stevens
# Episode 23500 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 23600 finished with total reward: 700. First driver picked was Will Stevens
# Episode 23700 finished with total reward: 1000. First driver picked was Max Chilton
# Episode 23800 finished with total reward: 0. First driver picked was Adrian Sutil
# Episode 23900 finished with total reward: 700. First driver picked was Will Stevens
# Episode 24000 finished with total reward: 800. First driver picked was Oliver Bearman
# Episode 24100 finished with total reward: 700. First driver picked was Logan Sargeant
# Episode 24200 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 24300 finished with total reward: 700. First driver picked was Pastor Maldonado
# Episode 24400 finished with total reward: 800. First driver picked was Lando Norris
# Episode 24500 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 24600 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 24700 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 24800 finished with total reward: 900. First driver picked was Oscar Piastri
# Episode 24900 finished with total reward: 0. First driver picked was Mick Schumacher
# Episode 25000 finished with total reward: 600. First driver picked was Daniil Kvyat
# Episode 25100 finished with total reward: 0. First driver picked was Adrian Sutil
# Episode 25200 finished with total reward: 1000. First driver picked was Jack Aitken
# Episode 25300 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 25400 finished with total reward: 800. First driver picked was Jack Aitken
# Episode 25500 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 25600 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 25700 finished with total reward: 600. First driver picked was Alexander Albon
# Episode 25800 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 25900 finished with total reward: 800. First driver picked was Jack Aitken
# Episode 26000 finished with total reward: 600. First driver picked was Zhou Guanyu
# Episode 26100 finished with total reward: 600. First driver picked was Mick Schumacher
# Episode 26200 finished with total reward: 900. First driver picked was Sergey Sirotkin
# Episode 26300 finished with total reward: 600. First driver picked was Jack Aitken
# Episode 26400 finished with total reward: 700. First driver picked was Jack Aitken
# Episode 26500 finished with total reward: 800. First driver picked was Jack Aitken
# Episode 26600 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 26700 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 26800 finished with total reward: 0. First driver picked was Max Verstappen
# Episode 26900 finished with total reward: 1000. First driver picked was George Russell
# Episode 27000 finished with total reward: 800. First driver picked was Liam Lawson
# Episode 27100 finished with total reward: 900. First driver picked was Nicholas Latifi
# Episode 27200 finished with total reward: 700. First driver picked was Brendon Hartley
# Episode 27300 finished with total reward: 0. First driver picked was Nico Hulkenberg
# Episode 27400 finished with total reward: 0. First driver picked was Logan Sargeant
# Episode 27500 finished with total reward: 0. First driver picked was Roberto Merhi
# Episode 27600 finished with total reward: 800. First driver picked was Liam Lawson
# Episode 27700 finished with total reward: 800. First driver picked was Lando Norris
# Episode 27800 finished with total reward: 0. First driver picked was Logan Sargeant
# Episode 27900 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 28000 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 28100 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 28200 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 28300 finished with total reward: 600. First driver picked was Mick Schumacher
# Episode 28400 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 28500 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 28600 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 28700 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 28800 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 28900 finished with total reward: 1000. First driver picked was Pascal Wehrlein
# Episode 29000 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 29100 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 29200 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 29300 finished with total reward: 800. First driver picked was Logan Sargeant
# Episode 29400 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 29500 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 29600 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 29700 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 29800 finished with total reward: 900. First driver picked was Jack Aitken
# Episode 29900 finished with total reward: 600. First driver picked was Jack Aitken
# Episode 30000 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 30100 finished with total reward: 1000. First driver picked was Jack Aitken
# Episode 30200 finished with total reward: 1000. First driver picked was Jack Aitken
# Episode 30300 finished with total reward: 900. First driver picked was Jack Aitken
# Episode 30400 finished with total reward: 600. First driver picked was Logan Sargeant
# Episode 30500 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 30600 finished with total reward: 600. First driver picked was Jules Bianchi
# Episode 30700 finished with total reward: 900. First driver picked was Pascal Wehrlein
# Episode 30800 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 30900 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 31000 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 31100 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 31200 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 31300 finished with total reward: 800. First driver picked was Nico Hulkenberg
# Episode 31400 finished with total reward: 0. First driver picked was Will Stevens
# Episode 31500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 31600 finished with total reward: 0. First driver picked was Pietro Fittipaldi
# Episode 31700 finished with total reward: 600. First driver picked was Will Stevens
# Episode 31800 finished with total reward: 700. First driver picked was Logan Sargeant
# Episode 31900 finished with total reward: 800. First driver picked was Will Stevens
# Episode 32000 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 32100 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 32200 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 32300 finished with total reward: 1000. First driver picked was Jack Aitken
# Episode 32400 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 32500 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 32600 finished with total reward: 600. First driver picked was Carlos Sainz
# Episode 32700 finished with total reward: 900. First driver picked was Jack Aitken
# Episode 32800 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 32900 finished with total reward: 600. First driver picked was Paul di Resta
# Episode 33000 finished with total reward: 0. First driver picked was Paul di Resta
# Episode 33100 finished with total reward: 600. First driver picked was Romain Grosjean
# Episode 33200 finished with total reward: 0. First driver picked was Mick Schumacher
# Episode 33300 finished with total reward: 1000. First driver picked was Nyck de Vries
# Episode 33400 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 33500 finished with total reward: 0. First driver picked was Will Stevens
# Episode 33600 finished with total reward: 800. First driver picked was Jack Aitken
# Episode 33700 finished with total reward: 900. First driver picked was Jack Aitken
# Episode 33800 finished with total reward: 800. First driver picked was Jack Aitken
# Episode 33900 finished with total reward: 600. First driver picked was Jack Aitken
# Episode 34000 finished with total reward: 0. First driver picked was Esteban Ocon
# Episode 34100 finished with total reward: 800. First driver picked was Esteban Ocon
# Episode 34200 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 34300 finished with total reward: 0. First driver picked was Alexander Rossi
# Episode 34400 finished with total reward: 0. First driver picked was Alexander Rossi
# Episode 34500 finished with total reward: 800. First driver picked was Pietro Fittipaldi
# Episode 34600 finished with total reward: 0. First driver picked was Roberto Merhi
# Episode 34700 finished with total reward: 0. First driver picked was Lando Norris
# Episode 34800 finished with total reward: 900. First driver picked was Valtteri Bottas
# Episode 34900 finished with total reward: 600. First driver picked was Jack Aitken
# Episode 35000 finished with total reward: 1000. First driver picked was Pierre Gasly
# Episode 35100 finished with total reward: 600. First driver picked was Brendon Hartley
# Episode 35200 finished with total reward: 800. First driver picked was Pierre Gasly
# Episode 35300 finished with total reward: 0. First driver picked was Mick Schumacher
# Episode 35400 finished with total reward: 1000. First driver picked was George Russell
# Episode 35500 finished with total reward: 600. First driver picked was George Russell
# Episode 35600 finished with total reward: 1000. First driver picked was George Russell
# Episode 35700 finished with total reward: 900. First driver picked was George Russell
# Episode 35800 finished with total reward: 600. First driver picked was George Russell
# Episode 35900 finished with total reward: 800. First driver picked was Nyck de Vries
# Episode 36000 finished with total reward: 900. First driver picked was Liam Lawson
# Episode 36100 finished with total reward: 600. First driver picked was Pietro Fittipaldi
# Episode 36200 finished with total reward: 0. First driver picked was Pietro Fittipaldi
# Episode 36300 finished with total reward: 900. First driver picked was Pietro Fittipaldi
# Episode 36400 finished with total reward: 0. First driver picked was George Russell
# Episode 36500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 36600 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 36700 finished with total reward: 0. First driver picked was Sergey Sirotkin
# Episode 36800 finished with total reward: 600. First driver picked was Robert Kubica
# Episode 36900 finished with total reward: 900. First driver picked was Nico Hulkenberg
# Episode 37000 finished with total reward: 0. First driver picked was Logan Sargeant
# Episode 37100 finished with total reward: 900. First driver picked was Nikita Mazepin
# Episode 37200 finished with total reward: 800. First driver picked was Will Stevens
# Episode 37300 finished with total reward: 0. First driver picked was Will Stevens
# Episode 37400 finished with total reward: 0. First driver picked was Will Stevens
# Episode 37500 finished with total reward: 1000. First driver picked was Nikita Mazepin
# Episode 37600 finished with total reward: 600. First driver picked was Sergey Sirotkin
# Episode 37700 finished with total reward: 0. First driver picked was Will Stevens
# Episode 37800 finished with total reward: 0. First driver picked was Will Stevens
# Episode 37900 finished with total reward: 1000. First driver picked was Lando Norris
# Episode 38000 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 38100 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 38200 finished with total reward: 0. First driver picked was Roberto Merhi
# Episode 38300 finished with total reward: 0. First driver picked was Esteban Gutierrez
# Episode 38400 finished with total reward: 0. First driver picked was Mick Schumacher
# Episode 38500 finished with total reward: 0. First driver picked was Brendon Hartley
# Episode 38600 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 38700 finished with total reward: 0. First driver picked was Lando Norris
# Episode 38800 finished with total reward: 800. First driver picked was Lando Norris
# Episode 38900 finished with total reward: 900. First driver picked was George Russell
# Episode 39000 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 39100 finished with total reward: 0. First driver picked was Alexander Rossi
# Episode 39200 finished with total reward: 0. First driver picked was Paul di Resta
# Episode 39300 finished with total reward: 600. First driver picked was Daniil Kvyat
# Episode 39400 finished with total reward: 800. First driver picked was Stoffel Vandoorne
# Episode 39500 finished with total reward: 600. First driver picked was Lance Stroll
# Episode 39600 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 39700 finished with total reward: 900. First driver picked was Pascal Wehrlein
# Episode 39800 finished with total reward: 700. First driver picked was Oscar Piastri
# Episode 39900 finished with total reward: 0. First driver picked was Lance Stroll
# Episode 40000 finished with total reward: 0. First driver picked was Antonio Giovinazzi
# Episode 40100 finished with total reward: 0. First driver picked was Antonio Giovinazzi
# Episode 40200 finished with total reward: 0. First driver picked was Max Chilton
# Episode 40300 finished with total reward: 800. First driver picked was Oscar Piastri
# Episode 40400 finished with total reward: 0. First driver picked was Esteban Ocon
# Episode 40500 finished with total reward: 0. First driver picked was Sergio Perez
# Episode 40600 finished with total reward: 0. First driver picked was Logan Sargeant
# Episode 40700 finished with total reward: 800. First driver picked was Kamui Kobayashi
# Episode 40800 finished with total reward: 700. First driver picked was Roberto Merhi
# Episode 40900 finished with total reward: 0. First driver picked was Max Chilton
# Episode 41000 finished with total reward: 600. First driver picked was Sergey Sirotkin
# Episode 41100 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 41200 finished with total reward: 1000. First driver picked was Nico Hulkenberg
# Episode 41300 finished with total reward: 700. First driver picked was Nico Hulkenberg
# Episode 41400 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 41500 finished with total reward: 600. First driver picked was Felipe Nasr
# Episode 41600 finished with total reward: 900. First driver picked was Nico Hulkenberg
# Episode 41700 finished with total reward: 0. First driver picked was Nico Hulkenberg
# Episode 41800 finished with total reward: 600. First driver picked was Pierre Gasly
# Episode 41900 finished with total reward: 0. First driver picked was Jules Bianchi
# Episode 42000 finished with total reward: 900. First driver picked was Mick Schumacher
# Episode 42100 finished with total reward: 1000. First driver picked was Mick Schumacher
# Episode 42200 finished with total reward: 1000. First driver picked was Pierre Gasly
# Episode 42300 finished with total reward: 600. First driver picked was Pierre Gasly
# Episode 42400 finished with total reward: 900. First driver picked was Max Chilton
# Episode 42500 finished with total reward: 600. First driver picked was Max Chilton
# Episode 42600 finished with total reward: 600. First driver picked was Felipe Nasr
# Episode 42700 finished with total reward: 1000. First driver picked was Jack Aitken
# Episode 42800 finished with total reward: 700. First driver picked was Jack Aitken
# Episode 42900 finished with total reward: 0. First driver picked was Pierre Gasly
# Episode 43000 finished with total reward: 0. First driver picked was Kevin Magnussen
# Episode 43100 finished with total reward: 700. First driver picked was Pierre Gasly
# Episode 43200 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 43300 finished with total reward: 900. First driver picked was Pierre Gasly
# Episode 43400 finished with total reward: 600. First driver picked was Brendon Hartley
# Episode 43500 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 43600 finished with total reward: 1000. First driver picked was Pierre Gasly
# Episode 43700 finished with total reward: 0. First driver picked was Charles Leclerc
# Episode 43800 finished with total reward: 800. First driver picked was Esteban Ocon
# Episode 43900 finished with total reward: 900. First driver picked was Will Stevens
# Episode 44000 finished with total reward: 800. First driver picked was Will Stevens
# Episode 44100 finished with total reward: 800. First driver picked was Will Stevens
# Episode 44200 finished with total reward: 800. First driver picked was Sebastian Vettel
# Episode 44300 finished with total reward: 0. First driver picked was Will Stevens
# Episode 44400 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 44500 finished with total reward: 800. First driver picked was Will Stevens
# Episode 44600 finished with total reward: 0. First driver picked was Will Stevens
# Episode 44700 finished with total reward: 700. First driver picked was Will Stevens
# Episode 44800 finished with total reward: 0. First driver picked was Lando Norris
# Episode 44900 finished with total reward: 1000. First driver picked was Romain Grosjean
# Episode 45000 finished with total reward: 0. First driver picked was Esteban Ocon
# Episode 45100 finished with total reward: 0. First driver picked was Will Stevens
# Episode 45200 finished with total reward: 600. First driver picked was Roberto Merhi
# Episode 45300 finished with total reward: 0. First driver picked was Lando Norris
# Episode 45400 finished with total reward: 0. First driver picked was Oliver Bearman
# Episode 45500 finished with total reward: 1000. First driver picked was Max Chilton
# Episode 45600 finished with total reward: 0. First driver picked was Max Chilton
# Episode 45700 finished with total reward: 0. First driver picked was Max Chilton
# Episode 45800 finished with total reward: 1000. First driver picked was Max Chilton
# Episode 45900 finished with total reward: 800. First driver picked was Max Chilton
# Episode 46000 finished with total reward: 600. First driver picked was Max Chilton
# Episode 46100 finished with total reward: 700. First driver picked was Rio Haryanto
# Episode 46200 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 46300 finished with total reward: 0. First driver picked was Max Verstappen
# Episode 46400 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 46500 finished with total reward: 0. First driver picked was George Russell
# Episode 46600 finished with total reward: 0. First driver picked was Nikita Mazepin
# Episode 46700 finished with total reward: 0. First driver picked was Will Stevens
# Episode 46800 finished with total reward: 0. First driver picked was Adrian Sutil
# Episode 46900 finished with total reward: 600. First driver picked was Pascal Wehrlein
# Episode 47000 finished with total reward: 1000. First driver picked was Pietro Fittipaldi
# Episode 47100 finished with total reward: 900. First driver picked was Max Chilton
# Episode 47200 finished with total reward: 0. First driver picked was Max Chilton
# Episode 47300 finished with total reward: 0. First driver picked was Pietro Fittipaldi
# Episode 47400 finished with total reward: 700. First driver picked was Pascal Wehrlein
# Episode 47500 finished with total reward: 800. First driver picked was Mick Schumacher
# Episode 47600 finished with total reward: 0. First driver picked was Daniil Kvyat
# Episode 47700 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 47800 finished with total reward: 1000. First driver picked was Max Chilton
# Episode 47900 finished with total reward: 0. First driver picked was Paul di Resta
# Episode 48000 finished with total reward: 800. First driver picked was Max Chilton
# Episode 48100 finished with total reward: 0. First driver picked was Antonio Giovinazzi
# Episode 48200 finished with total reward: 900. First driver picked was Jack Aitken
# Episode 48300 finished with total reward: 0. First driver picked was Lance Stroll
# Episode 48400 finished with total reward: 0. First driver picked was Lando Norris
# Episode 48500 finished with total reward: 800. First driver picked was Mick Schumacher
# Episode 48600 finished with total reward: 800. First driver picked was George Russell
# Episode 48700 finished with total reward: 800. First driver picked was Will Stevens
# Episode 48800 finished with total reward: 1000. First driver picked was George Russell
# Episode 48900 finished with total reward: 600. First driver picked was George Russell
# Episode 49000 finished with total reward: 1000. First driver picked was George Russell
# Episode 49100 finished with total reward: 600. First driver picked was George Russell
# Episode 49200 finished with total reward: 0. First driver picked was George Russell
# Episode 49300 finished with total reward: 1000. First driver picked was George Russell
# Episode 49400 finished with total reward: 0. First driver picked was George Russell
# Episode 49500 finished with total reward: 0. First driver picked was George Russell
# Episode 49600 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 49700 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 49800 finished with total reward: 0. First driver picked was Sergio Perez
# Episode 49900 finished with total reward: 0. First driver picked was Nico Hulkenberg
# Episode 50000 finished with total reward: 900. First driver picked was George Russell
# Episode 50100 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 50200 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 50300 finished with total reward: 600. First driver picked was Esteban Ocon
# Episode 50400 finished with total reward: 0. First driver picked was Esteban Ocon
# Episode 50500 finished with total reward: 0. First driver picked was Paul di Resta
# Episode 50600 finished with total reward: 900. First driver picked was Esteban Ocon
# Episode 50700 finished with total reward: 900. First driver picked was Esteban Ocon
# Episode 50800 finished with total reward: 0. First driver picked was Nico Hulkenberg
# Episode 50900 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 51000 finished with total reward: 600. First driver picked was Lewis Hamilton
# Episode 51100 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 51200 finished with total reward: 0. First driver picked was Felipe Nasr
# Episode 51300 finished with total reward: 0. First driver picked was Paul di Resta
# Episode 51400 finished with total reward: 0. First driver picked was Paul di Resta
# Episode 51500 finished with total reward: 1000. First driver picked was Esteban Ocon
# Episode 51600 finished with total reward: 0. First driver picked was Yuki Tsunoda
# Episode 51700 finished with total reward: 0. First driver picked was Esteban Ocon
# Episode 51800 finished with total reward: 0. First driver picked was Sergey Sirotkin
# Episode 51900 finished with total reward: 0. First driver picked was Esteban Ocon
# Episode 52000 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 52100 finished with total reward: 900. First driver picked was Esteban Ocon
# Episode 52200 finished with total reward: 800. First driver picked was Esteban Ocon
# Episode 52300 finished with total reward: 700. First driver picked was Paul di Resta
# Episode 52400 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 52500 finished with total reward: 900. First driver picked was Paul di Resta
# Episode 52600 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 52700 finished with total reward: 700. First driver picked was Paul di Resta
# Episode 52800 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 52900 finished with total reward: 900. First driver picked was Paul di Resta
# Episode 53000 finished with total reward: 600. First driver picked was Paul di Resta
# Episode 53100 finished with total reward: 0. First driver picked was Andre Lotterer
# Episode 53200 finished with total reward: 700. First driver picked was Pierre Gasly
# Episode 53300 finished with total reward: 0. First driver picked was Sergey Sirotkin
# Episode 53400 finished with total reward: 0. First driver picked was Charles Leclerc
# Episode 53500 finished with total reward: 0. First driver picked was Nicholas Latifi
# Episode 53600 finished with total reward: 600. First driver picked was Alexander Albon
# Episode 53700 finished with total reward: 0. First driver picked was Antonio Giovinazzi
# Episode 53800 finished with total reward: 600. First driver picked was Jack Aitken
# Episode 53900 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 54000 finished with total reward: 1000. First driver picked was Paul di Resta
# Episode 54100 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 54200 finished with total reward: 1000. First driver picked was Felipe Nasr
# Episode 54300 finished with total reward: 1000. First driver picked was Adrian Sutil
# Episode 54400 finished with total reward: 600. First driver picked was Felipe Massa
# Episode 54500 finished with total reward: 0. First driver picked was Rio Haryanto
# Episode 54600 finished with total reward: 0. First driver picked was Nicholas Latifi
# Episode 54700 finished with total reward: 0. First driver picked was George Russell
# Episode 54800 finished with total reward: 700. First driver picked was George Russell
# Episode 54900 finished with total reward: 700. First driver picked was Mick Schumacher
# Episode 55000 finished with total reward: 800. First driver picked was George Russell
# Episode 55100 finished with total reward: 600. First driver picked was Pierre Gasly
# Episode 55200 finished with total reward: 1000. First driver picked was Pierre Gasly
# Episode 55300 finished with total reward: 800. First driver picked was Pierre Gasly
# Episode 55400 finished with total reward: 600. First driver picked was Pierre Gasly
# Episode 55500 finished with total reward: 700. First driver picked was Antonio Giovinazzi
# Episode 55600 finished with total reward: 700. First driver picked was Sergio Perez
# Episode 55700 finished with total reward: 0. First driver picked was Pietro Fittipaldi
# Episode 55800 finished with total reward: 1000. First driver picked was Alexander Rossi
# Episode 55900 finished with total reward: 700. First driver picked was Alexander Rossi
# Episode 56000 finished with total reward: 900. First driver picked was Alexander Rossi
# Episode 56100 finished with total reward: 1000. First driver picked was Sergey Sirotkin
# Episode 56200 finished with total reward: 0. First driver picked was Alexander Rossi
# Episode 56300 finished with total reward: 600. First driver picked was Nico Rosberg
# Episode 56400 finished with total reward: 700. First driver picked was Adrian Sutil
# Episode 56500 finished with total reward: 700. First driver picked was Adrian Sutil
# Episode 56600 finished with total reward: 600. First driver picked was Adrian Sutil
# Episode 56700 finished with total reward: 800. First driver picked was Felipe Nasr
# Episode 56800 finished with total reward: 600. First driver picked was Adrian Sutil
# Episode 56900 finished with total reward: 600. First driver picked was Robert Kubica
# ...
# Episode 161500 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 161600 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 161700 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 161800 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 161900 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 162000 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 162100 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 162200 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 162300 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 162400 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 162500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 162600 finished with total reward: 0. First driver picked was Oliver Bearman
# Episode 162700 finished with total reward: 0. First driver picked was Stoffel Vandoorne
# Episode 162800 finished with total reward: 700. First driver picked was Kamui Kobayashi
# Episode 162900 finished with total reward: 600. First driver picked was Kamui Kobayashi
# Episode 163000 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 163100 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 163200 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 163300 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 163400 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 163500 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 163600 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 163700 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 163800 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 163900 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 164000 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 164100 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 164200 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 164300 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 164400 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 164500 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 164600 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 164700 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 164800 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 164900 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 165000 finished with total reward: 700. First driver picked was Esteban Ocon
# Episode 165100 finished with total reward: 900. First driver picked was Oscar Piastri
# Episode 165200 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 165300 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 165400 finished with total reward: 600. First driver picked was Max Chilton
# Episode 165500 finished with total reward: 700. First driver picked was Andre Lotterer
# Episode 165600 finished with total reward: 0. First driver picked was Lando Norris
# Episode 165700 finished with total reward: 0. First driver picked was Lando Norris
# Episode 165800 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 165900 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 166000 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 166100 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 166200 finished with total reward: 0. First driver picked was Oliver Bearman
# Episode 166300 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 166400 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 166500 finished with total reward: 0. First driver picked was Lando Norris
# Episode 166600 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 166700 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 166800 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 166900 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 167000 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 167100 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 167200 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 167300 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 167400 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 167500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 167600 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 167700 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 167800 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 167900 finished with total reward: 600. First driver picked was Sebastian Vettel
# Episode 168000 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 168100 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 168200 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 168300 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 168400 finished with total reward: 800. First driver picked was Esteban Ocon
# Episode 168500 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 168600 finished with total reward: 700. First driver picked was Roberto Merhi
# Episode 168700 finished with total reward: 800. First driver picked was Kamui Kobayashi
# Episode 168800 finished with total reward: 800. First driver picked was Sergio Perez
# Episode 168900 finished with total reward: 700. First driver picked was Pascal Wehrlein
# Episode 169000 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 169100 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 169200 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 169300 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 169400 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 169500 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 169600 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 169700 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 169800 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 169900 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 170000 finished with total reward: 0. First driver picked was Nico Rosberg
# Episode 170100 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 170200 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 170300 finished with total reward: 0. First driver picked was Brendon Hartley
# Episode 170400 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 170500 finished with total reward: 700. First driver picked was Brendon Hartley
# Episode 170600 finished with total reward: 900. First driver picked was Will Stevens
# Episode 170700 finished with total reward: 700. First driver picked was Pietro Fittipaldi
# Episode 170800 finished with total reward: 0. First driver picked was Will Stevens
# Episode 170900 finished with total reward: 800. First driver picked was Max Chilton
# Episode 171000 finished with total reward: 900. First driver picked was Nicholas Latifi
# Episode 171100 finished with total reward: 700. First driver picked was Adrian Sutil
# Episode 171200 finished with total reward: 600. First driver picked was Liam Lawson
# Episode 171300 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 171400 finished with total reward: 800. First driver picked was Sergey Sirotkin
# Episode 171500 finished with total reward: 0. First driver picked was Logan Sargeant
# Episode 171600 finished with total reward: 1000. First driver picked was Yuki Tsunoda
# Episode 171700 finished with total reward: 900. First driver picked was Lando Norris
# Episode 171800 finished with total reward: 600. First driver picked was Sebastian Vettel
# Episode 171900 finished with total reward: 700. First driver picked was Nicholas Latifi
# Episode 172000 finished with total reward: 0. First driver picked was Carlos Sainz
# Episode 172100 finished with total reward: 0. First driver picked was Nicholas Latifi
# Episode 172200 finished with total reward: 700. First driver picked was Max Verstappen
# Episode 172300 finished with total reward: 600. First driver picked was Max Chilton
# Episode 172400 finished with total reward: 600. First driver picked was Jack Aitken
# Episode 172500 finished with total reward: 1000. First driver picked was Jack Aitken
# Episode 172600 finished with total reward: 700. First driver picked was Lando Norris
# Episode 172700 finished with total reward: 600. First driver picked was Pierre Gasly
# Episode 172800 finished with total reward: 800. First driver picked was Max Chilton
# Episode 172900 finished with total reward: 900. First driver picked was Roberto Merhi
# Episode 173000 finished with total reward: 800. First driver picked was Sergey Sirotkin
# Episode 173100 finished with total reward: 0. First driver picked was Romain Grosjean
# Episode 173200 finished with total reward: 700. First driver picked was Oliver Bearman
# Episode 173300 finished with total reward: 800. First driver picked was Stoffel Vandoorne
# Episode 173400 finished with total reward: 800. First driver picked was Jenson Button
# Episode 173500 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 173600 finished with total reward: 600. First driver picked was Kamui Kobayashi
# Episode 173700 finished with total reward: 800. First driver picked was Pierre Gasly
# Episode 173800 finished with total reward: 600. First driver picked was Felipe Nasr
# Episode 173900 finished with total reward: 0. First driver picked was Fernando Alonso
# Episode 174000 finished with total reward: 0. First driver picked was Logan Sargeant
# Episode 174100 finished with total reward: 800. First driver picked was Pierre Gasly
# Episode 174200 finished with total reward: 1000. First driver picked was Will Stevens
# Episode 174300 finished with total reward: 600. First driver picked was Will Stevens
# Episode 174400 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 174500 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 174600 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 174700 finished with total reward: 0. First driver picked was Daniel Ricciardo
# Episode 174800 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 174900 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 175000 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 175100 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 175200 finished with total reward: 0. First driver picked was Kimi Raikkonen
# Episode 175300 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 175400 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 175500 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 175600 finished with total reward: 600. First driver picked was Zhou Guanyu
# Episode 175700 finished with total reward: 0. First driver picked was Stoffel Vandoorne
# Episode 175800 finished with total reward: 700. First driver picked was Jolyon Palmer
# Episode 175900 finished with total reward: 600. First driver picked was Fernando Alonso
# Episode 176000 finished with total reward: 0. First driver picked was Paul di Resta
# Episode 176100 finished with total reward: 600. First driver picked was Nicholas Latifi
# Episode 176200 finished with total reward: 0. First driver picked was Kamui Kobayashi
# Episode 176300 finished with total reward: 600. First driver picked was Adrian Sutil
# Episode 176400 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 176500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 176600 finished with total reward: 800. First driver picked was Paul di Resta
# Episode 176700 finished with total reward: 600. First driver picked was Pascal Wehrlein
# Episode 176800 finished with total reward: 800. First driver picked was Sebastian Vettel
# Episode 176900 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 177000 finished with total reward: 0. First driver picked was George Russell
# Episode 177100 finished with total reward: 0. First driver picked was Romain Grosjean
# Episode 177200 finished with total reward: 600. First driver picked was Lance Stroll
# Episode 177300 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 177400 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 177500 finished with total reward: 0. First driver picked was Jolyon Palmer
# Episode 177600 finished with total reward: 0. First driver picked was Nico Hulkenberg
# Episode 177700 finished with total reward: 800. First driver picked was Nico Hulkenberg
# Episode 177800 finished with total reward: 600. First driver picked was Logan Sargeant
# Episode 177900 finished with total reward: 0. First driver picked was Roberto Merhi
# Episode 178000 finished with total reward: 0. First driver picked was Lando Norris
# Episode 178100 finished with total reward: 0. First driver picked was Marcus Ericsson
# Episode 178200 finished with total reward: 700. First driver picked was Jack Aitken
# Episode 178300 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 178400 finished with total reward: 0. First driver picked was Jack Aitken
# Episode 178500 finished with total reward: 0. First driver picked was Sebastian Vettel
# Episode 178600 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 178700 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 178800 finished with total reward: 800. First driver picked was Pietro Fittipaldi
# Episode 178900 finished with total reward: 0. First driver picked was Alexander Albon
# Episode 179000 finished with total reward: 600. First driver picked was Jolyon Palmer
# Episode 179100 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 179200 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 179300 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 179400 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 179500 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 179600 finished with total reward: 1000. First driver picked was Jolyon Palmer
# Episode 179700 finished with total reward: 1000. First driver picked was Lando Norris
# Episode 179800 finished with total reward: 900. First driver picked was Jolyon Palmer
# Episode 179900 finished with total reward: 800. First driver picked was Jolyon Palmer
# Episode 180000 finished with total reward: 900. First driver picked was Jolyon Palmer

# %%
agent.exploration_rate = 1

# %%
# Set exploration rate to 0 to use the learned policy without exploration
agent.exploration_rate = 0

# Set up a counter for the number of wins
num_wins = 0
sum_pts = 0
num_evaluation_episodes = 10000

for episode in range(num_evaluation_episodes):
    observation = env.reset()
    done = False
    
    while not done:
        # Agent always exploits the best action from Q-table
        action = agent.choose_action(observation)
        observation, reward, done, info = env.step(action)
        
        # If the reward is positive, it means the agent found the correct driver
        if reward > 0:
            num_wins += 1
        sum_pts += reward

# Calculate the winning percentage
winning_percentage = (num_wins / num_evaluation_episodes) * 100
average_points = sum_pts / num_evaluation_episodes
ppw = sum_pts / num_wins
guesses = (700 - (len(df)*ppw+100)/len(df))/100 # approximate

print(f"Winning percentage over {num_evaluation_episodes} games: {winning_percentage}%")
print(f"Average points over {num_evaluation_episodes} games: {average_points}")
print(f"Average points per win {ppw}")
print(f"Average guesses per win {guesses}")
# Out:
# Winning percentage over 10000 games: 91.13%
# Average points over 10000 games: 281.38
# Average points per win 308.7676945023593
# Average guesses per win 3.8947791953272843

# %%
import pickle
# Saving the agent instance to a file
with open('agent_4_25_2024.pkl', 'wb') as file:
    pickle.dump(agent, file)
